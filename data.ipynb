# %%
import numpy  as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#        ID     Updated  Confirmed  ConfirmedChange  Deaths  DeathsChange  \
# 0  338995  01/21/2020        262              NaN     0.0           NaN
# 1  338996  01/22/2020        313             51.0     0.0           0.0
# 2  338997  01/23/2020        578            265.0     0.0           0.0
# 3  338998  01/24/2020        841            263.0     0.0           0.0
# 4  338999  01/25/2020       1320            479.0     0.0           0.0
#
#    Recovered  RecoveredChange  Latitude  Longitude ISO2 ISO3 Country_Region  \
# 0        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 1        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 2        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 3        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 4        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
#
#   AdminRegion1 AdminRegion2
# 0          NaN          NaN
# ...

# %%
indonesia = data[data['Country_Region'] == 'Indonesia']

# %%
indonesia.groupby('AdminRegion1').sum()
# Out:
#                               ID  Confirmed  ConfirmedChange     Deaths  \
# AdminRegion1
# Aceh                 32363819815    1451245            123.0   106514.0
# Bali                 32283690437    3505805            576.0   211224.0
# Bangka-Belitung      32271939014     545646           1618.0    32635.0
# Banten               32332423638    3053800            215.0   182212.0
# Bengkulu             32099424660     519496            629.0    33007.0
# Central Java         32290570557   13788880          -1624.0  1476254.0
# Central Kalimantan   32345279886    1622430            716.0    89992.0
# Central Sulawesi     32273199427     708975            668.0    50997.0
# East Java            32290666624   15718473          -3269.0  2114847.0
# East Kalimantan      32279916795    4873459           1573.0   285204.0
# East Nusa Tenggara   32262074157     519231            413.0    48026.0
# Gorontalo            32280461224     759117            571.0    34081.0
# ...

# %%
Yogyakarta = indonesia[indonesia['AdminRegion1'] == 'Yogyakarta']


plt.plot(Yogyakarta['Updated'], Yogyakarta['Deaths'] ,label='Deaths')
plt.plot(Yogyakarta['Updated'], Yogyakarta['Confirmed'], label='Confirmed')
plt.plot(Yogyakarta['Updated'], Yogyakarta['Recovered'] ,label='Recovered')

plt.legend()
plt.show()

# %%
Central_Java = indonesia[indonesia['AdminRegion1'] == 'Central Java']

plt.plot(Central_Java['Updated'], Central_Java['Deaths'] ,label='Deaths')
plt.plot(Central_Java['Updated'], Central_Java['Confirmed'], label='Confirmed')
plt.plot(Central_Java['Updated'], Central_Java['Recovered'] ,label='Recovered')

plt.legend()
plt.show()

# %%
plt.plot(Central_Java['Updated'], Central_Java['Confirmed'] ,label='Jawa')
plt.plot(yogyakarta['Updated'], yogyakarta['Confirmed'], label='jogja')

plt.legend()
plt.show()

# %%
plt.plot(Central_Java['Updated'], Central_Java['Deaths'] ,label='Jawa')
plt.plot(yogyakarta['Updated'], yogyakarta['Deaths'], label='jogja')

plt.legend()
plt.show()

# %%
plt.plot(Central_Java['Updated'], Central_Java['Recovered'] ,label='Jawa')
plt.plot(yogyakarta['Updated'], yogyakarta['Recovered'], label='jogja')

plt.legend()
plt.show()
